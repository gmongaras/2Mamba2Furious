# %%
import torch
import numpy as np

# %%
def forward(X, A, V, mask):
    M = (A[..., :, None] - A[..., None, :]).masked_fill(~mask, -torch.inf).exp()
    O = M * X
    return O @ V

def manual_grad(X, A, V, mask):
    X = X.clone().detach()
    A = A.clone().detach().requires_grad_()
    V = V.clone().detach()
    mask = mask.clone().detach()
    out = forward(X, A, V, mask)
    out.sum().backward()
    return A.grad

class Function(torch.autograd.Function):
    @staticmethod
    def forward(ctx, X, A, V, mask):
        ctx.save_for_backward(X, A, V, mask)
        return forward(X, A, V, mask)

    @staticmethod
    def backward(ctx, prev_grad):
        X, A, V, mask = ctx.saved_tensors
        
        M = (A[..., :, None] - A[..., None, :]).masked_fill(~mask, -torch.inf).exp()
        da = prev_grad @ V.mT
        vals = da * M * X
        
        A_grad = vals.sum(-1) - vals.sum(-2)
        
        return None, A_grad, None, None

# %%
N = 4
H = 4
S = 1024
d = 64

X = torch.randn(N, H, S, S).cuda().detach()
A = (-torch.nn.functional.softplus(torch.randn(N, H, S) * 0.1).cuda().cumsum(-1)).detach().requires_grad_()
V = torch.randn(N, H, S, d).cuda().detach()
mask = torch.tril(torch.ones(S, S)).bool()[None, None, ...].cuda().detach()

# %%
A_grad = manual_grad(X, A, V, mask)
A_grad
# Out:
# tensor([[[  1.1771,  -2.4842,  -0.8229,  ...,  -2.9013,  -8.1079,   5.7931],
#          [  0.7770,   0.4071,   6.8530,  ...,   3.4741,  -8.4213,   3.5603],
#          [ -4.3483,   1.9367,   2.1912,  ..., -14.8011,  12.6799,  -0.6350],
#          [-18.0781,  15.1313,   4.7784,  ...,  10.2108,  -9.6315,  15.0513]],
#
#         [[ -3.0058,   3.5219,  -0.3513,  ...,  -0.0805,  -1.3040,   2.3503],
#          [ -2.6475,   2.8694,   0.9606,  ...,  -0.8401,   1.6273,  -0.9460],
#          [  1.6462,   0.6906,  -2.9011,  ...,   4.2723,  13.6414, -14.4975],
#          [ -1.9470,   1.1767,   0.8330,  ...,  -6.4973,   7.4139,   2.7352]],
#
#         [[  1.9239,   7.2508,  -9.1321,  ...,   6.5867,  -0.0471,   2.4892],
#          [  2.3440,  -5.6813,   4.9629,  ...,  -3.3493,  -2.7129,   1.0615],
#          [ -2.6036,   0.2488,   0.3786,  ...,   1.3992,  -2.6434,   0.8331],
#          [  3.0142,  -0.6237,  -0.4436,  ...,  -0.0514,  -1.9302,  -1.3114]],
#
#         [[  0.5355,  -4.7543,   2.7631,  ...,  -1.5342,  10.6232, -10.1418],
#          [ -1.5409,   3.0933,   2.5039,  ...,   2.1376,  -4.3736,   8.9278],
#          [  2.0005,   3.1957,  -5.3786,  ...,   8.5715,  -3.6065,  -0.2953],
#          [ -3.0890,  18.2423, -18.8546,  ...,  -3.6966,  -3.7231,   3.9046]]],
#        device='cuda:0')

# %%
out = Function.apply(X, A, V, mask)

# %%
out.sum().backward()

# %%
A_grad_ = A.grad
A_grad_
# Out:
# tensor([[[  1.1771,  -2.4842,  -0.8229,  ...,  -2.9013,  -8.1079,   5.7931],
#          [  0.7770,   0.4071,   6.8530,  ...,   3.4741,  -8.4213,   3.5603],
#          [ -4.3483,   1.9367,   2.1912,  ..., -14.8011,  12.6799,  -0.6350],
#          [-18.0781,  15.1313,   4.7784,  ...,  10.2108,  -9.6315,  15.0513]],
#
#         [[ -3.0058,   3.5219,  -0.3513,  ...,  -0.0805,  -1.3040,   2.3503],
#          [ -2.6475,   2.8694,   0.9606,  ...,  -0.8401,   1.6273,  -0.9460],
#          [  1.6462,   0.6906,  -2.9011,  ...,   4.2723,  13.6414, -14.4975],
#          [ -1.9471,   1.1767,   0.8330,  ...,  -6.4973,   7.4139,   2.7352]],
#
#         [[  1.9239,   7.2508,  -9.1321,  ...,   6.5867,  -0.0471,   2.4892],
#          [  2.3440,  -5.6813,   4.9629,  ...,  -3.3493,  -2.7129,   1.0615],
#          [ -2.6036,   0.2488,   0.3786,  ...,   1.3992,  -2.6434,   0.8331],
#          [  3.0142,  -0.6237,  -0.4436,  ...,  -0.0514,  -1.9302,  -1.3114]],
#
#         [[  0.5355,  -4.7543,   2.7631,  ...,  -1.5342,  10.6232, -10.1418],
#          [ -1.5409,   3.0933,   2.5039,  ...,   2.1376,  -4.3736,   8.9278],
#          [  2.0005,   3.1957,  -5.3786,  ...,   8.5715,  -3.6065,  -0.2953],
#          [ -3.0890,  18.2423, -18.8546,  ...,  -3.6966,  -3.7231,   3.9046]]],
#        device='cuda:0')

# %%
(A_grad - A_grad_).abs().max()
# Out:
# tensor(7.6294e-06, device='cuda:0')

# %%
torch.autograd.gradcheck(Function.apply, (X, A, V, mask), eps=1e-4)
# Out:
# /users/gmongaras/miniconda3/lib/python3.10/site-packages/torch/autograd/gradcheck.py:922: UserWarning: Input #1 requires gradient and is not a double precision floating point or complex. This check will likely fail if all the inputs are not of double precision floating point or complex.
#   warnings.warn(
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 torch.autograd.gradcheck(Function.apply, (X, A, V, mask), eps=1e-4)
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/autograd/gradcheck.py:2055, in gradcheck(func, inputs, eps, atol, rtol, raise_exception, nondet_tol, check_undefined_grad, check_grad_dtypes, check_batched_grad, check_batched_forward_grad, check_forward_ad, check_backward_ad, fast_mode, masked)
#    2053         return False
#    2054 else:
# -> 2055     return _gradcheck_helper(**args)
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/autograd/gradcheck.py:2084, in _gradcheck_helper(func, inputs, eps, atol, rtol, nondet_tol, check_undefined_grad, check_grad_dtypes, check_batched_grad, check_batched_forward_grad, check_forward_ad, check_backward_ad, fast_mode, masked)
#    2079 _check_outputs(outputs)
#    2081 gradcheck_fn = functools.partial(
#    2082     _fast_gradcheck if fast_mode else _slow_gradcheck, masked=masked
#    2083 )
# -> 2084 _gradcheck_real_imag(
#    2085     gradcheck_fn,
#    2086     func,
#    2087     func_out,
#    2088     tupled_inputs,
#    2089     outputs,
#    2090     eps,
#    2091     rtol,
#    2092     atol,
#    2093     check_grad_dtypes,
#    2094     check_forward_ad=check_forward_ad,
#    2095     check_backward_ad=check_backward_ad,
#    2096     nondet_tol=nondet_tol,
#    2097     check_undefined_grad=check_undefined_grad,
#    2098 )
#    2100 if check_batched_forward_grad:
#    2101     _test_batched_grad_forward_ad(func, tupled_inputs)
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/autograd/gradcheck.py:1494, in _gradcheck_real_imag(gradcheck_fn, func, func_out, tupled_inputs, outputs, eps, rtol, atol, check_grad_dtypes, check_forward_ad, check_backward_ad, nondet_tol, check_undefined_grad)
#    1481         gradcheck_fn(
#    1482             real_fn,
#    1483             real_func_out,
#    (...)
#    1491             complex_indices=complex_out_indices,
#    1492         )
#    1493     else:
# -> 1494         gradcheck_fn(
#    1495             func,
#    1496             func_out,
#    1497             tupled_inputs,
#    1498             outputs,
#    1499             eps,
#    1500             rtol,
#    1501             atol,
#    1502             check_grad_dtypes,
#    1503             nondet_tol,
#    1504         )
#    1506 if check_forward_ad:
#    1507     complex_inp_indices = [
#    1508         i
#    1509         for i, inp in enumerate(tupled_inputs)
#    1510         if is_tensor_like(inp) and inp.is_complex()
#    1511     ]
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/autograd/gradcheck.py:1601, in _slow_gradcheck(func, func_out, tupled_inputs, outputs, eps, rtol, atol, check_grad_dtypes, nondet_tol, use_forward_ad, complex_indices, test_imag, masked)
#    1595     return _check_no_differentiable_outputs(
#    1596         func, tupled_inputs, func_out, eps=eps, is_forward_ad=use_forward_ad
#    1597     )
#    1598 tupled_inputs_numerical = tupled_inputs if masked else _densify(tupled_inputs)
#    1600 numerical = _transpose(
# -> 1601     _get_numerical_jacobian(
#    1602         func,
#    1603         tupled_inputs_numerical,
#    1604         func_out,
#    1605         eps=eps,
#    1606         is_forward_ad=use_forward_ad,
#    1607     )
#    1608 )
#    1609 # Note: [numerical vs analytical output length]
#    1610 # The numerical path returns jacobian quantity for all outputs, even if requires_grad of that
#    1611 # output is False. This behavior is necessary for _check_no_differentiable_outputs to work.
#    1612 numerical = [nj for o, nj in zip(func_out, numerical) if o.requires_grad]
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/autograd/gradcheck.py:299, in _get_numerical_jacobian(fn, inputs, outputs, target, eps, is_forward_ad)
#     294 inp_indices = [
#     295     i for i, a in enumerate(target) if is_tensor_like(a) and a.requires_grad
#     296 ]
#     297 for i, (inp, inp_idx) in enumerate(zip(_iter_tensors(target, True), inp_indices)):
#     298     jacobians += [
# --> 299         get_numerical_jacobian_wrt_specific_input(
#     300             fn,
#     301             inp_idx,
#     302             inputs,
#     303             outputs,
#     304             eps,
#     305             input=inp,
#     306             is_forward_ad=is_forward_ad,
#     307         )
#     308     ]
#     309 return jacobians
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/autograd/gradcheck.py:491, in get_numerical_jacobian_wrt_specific_input(fn, input_idx, inputs, outputs, eps, input, is_forward_ad)
#     485     jvp_fn = _get_numerical_jvp_fn(
#     486         wrapped_fn, input_to_perturb, eps, nbhd_checks_fn
#     487     )
#     488     jacobian_cols[d_idx] = _compute_numerical_jvps_wrt_specific_input(
#     489         jvp_fn, eps, x.is_complex(), is_forward_ad
#     490     )
# --> 491 return _combine_jacobian_cols(jacobian_cols, outputs, input, input.numel())
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/autograd/gradcheck.py:419, in _combine_jacobian_cols(jacobians_cols, outputs, input, numel)
#     414 def _combine_jacobian_cols(
#     415     jacobians_cols: Dict[int, List[torch.Tensor]], outputs, input, numel
#     416 ) -> Tuple[torch.Tensor, ...]:
#     417     # jacobian_cols maps column_idx -> output_idx -> single column of jacobian Tensor
#     418     # we return a list that maps output_idx -> full jacobian Tensor
# --> 419     jacobians = _allocate_jacobians_with_outputs(
#     420         outputs, numel, dtype=input.dtype if input.dtype.is_complex else None
#     421     )
#     422     for i, jacobian in enumerate(jacobians):
#     423         for k, v in jacobians_cols.items():
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/autograd/gradcheck.py:74, in _allocate_jacobians_with_outputs(output_tensors, numel_input, dtype, device)
#      66 def _allocate_jacobians_with_outputs(
#      67     output_tensors: Tuple, numel_input, dtype=None, device=None
#      68 ) -> Tuple[torch.Tensor, ...]:
#    (...)
#      71     # width of `t.numel`. Otherwise, for each tensor, returns a 1-d tensor with size
#      72     # (t.numel,).
#      73     options = {"dtype": dtype, "device": device, "layout": torch.strided}
# ---> 74     out: List[torch.Tensor] = [
#      75         t.new_zeros((numel_input, t.numel()), **options)
#      76         for t in output_tensors
#      77         if _is_float_or_complex_tensor(t)
#      78     ]
#      79     return tuple(out)
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/autograd/gradcheck.py:75, in <listcomp>(.0)
#      66 def _allocate_jacobians_with_outputs(
#      67     output_tensors: Tuple, numel_input, dtype=None, device=None
#      68 ) -> Tuple[torch.Tensor, ...]:
#    (...)
#      71     # width of `t.numel`. Otherwise, for each tensor, returns a 1-d tensor with size
#      72     # (t.numel,).
#      73     options = {"dtype": dtype, "device": device, "layout": torch.strided}
#      74     out: List[torch.Tensor] = [
# ---> 75         t.new_zeros((numel_input, t.numel()), **options)
#      76         for t in output_tensors
#      77         if _is_float_or_complex_tensor(t)
#      78     ]
#      79     return tuple(out)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 64.00 GiB. GPU 0 has a total capacity of 79.25 GiB of which 13.55 GiB is free. Process 1737049 has 988.00 MiB memory in use. Including non-PyTorch memory, this process has 64.72 GiB memory in use. Of the allocated memory 64.16 GiB is allocated by PyTorch, and 66.44 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
